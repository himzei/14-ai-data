# %%
# Do not reinvert the wheel

# %%
from faker import Faker 

fake = Faker()
fake.name()
# Out:
# 'Kelsey Wilson'

# %%
fake.address()
# Out:
# '83201 Hart Junction\nPotterview, GU 47633'

# %%
test_data = [(fake.name(), fake.address()) for _ in range(30)]
print(test_data)
# Out:
# [('Jennifer Rice', '1012 Hall Loaf\nNorth Nicolasfurt, PR 96774'), ('Kelly Johnson', '98820 Montoya Grove Apt. 747\nNorth Gregorychester, GU 45140'), ('Laura Williams', '2960 Robert Valleys Apt. 130\nSouth Thomas, IN 73186'), ('Jackson Parker', '5319 Steven Spur\nSouth Ashleyview, MI 25348'), ('Robin Ramirez', '3607 Lauren Throughway Suite 248\nAndersonshire, MD 64671'), ('Shane Moss', 'USNS Martin\nFPO AA 24883'), ('Robert Parks', '59455 Ashley Haven Apt. 148\nRussellside, NC 28107'), ('Keith Carrillo', '258 Smith Parks Apt. 940\nStephenburgh, MP 34742'), ('Eric Jimenez', '14543 Samantha Squares\nPort Carrie, NE 76889'), ('Stanley Schwartz', '478 Herman Estates Apt. 140\nPort Ericabury, TN 80872'), ('Cody Thompson', '859 Mcdonald Court Apt. 543\nPort Lisaview, AK 90019'), ('Catherine Ross', '9215 Barbara Islands\nEast Elizabeth, LA 96758'), ('Charles Andrews', '4560 Jennifer Road Suite 460\nPort Bobbyport, WA 74561'), ('Kristi Fuentes MD', '50660 Fleming Shoals\nAtkinstown, LA 16724
# ...
